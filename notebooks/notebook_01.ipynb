# %%
import sys
sys.executable
# Out:
# '/Users/aurawang/Desktop/prepare/ChatGPT plan/Github/biostat-digital-health-portfolio/.venv/bin/python'

# %% [markdown]
# # Wearable Health Analytics — Sample Heart Rate Dataset
#
# This notebook demonstrates the basic data import and summary workflow for heart rate signals using Python and pandas.

# %% [markdown]
# ## Data Preview and Basic Statistics
#
# We start by loading the sample heart rate dataset and verifying that the structure looks correct.

# %%
import pandas as pd

df = pd.read_csv("../data/sample_data.csv")
print(df.head())
print("Rows:", len(df))
print("HR mean:", df["hr"].mean())
# Out:
#    id  hr
# 0   1  70
# 1   2  72
# 2   3  68
# 3   4  80
# 4   5  76
# Rows: 5
# HR mean: 73.2

# %%
print(df["hr"].max())
# Out:
# 80

# %%
print("Shape:", df.shape)
print("\nData Types:")
print(df.dtypes)
print("\nMissing Values:")
print(df.isna().sum())
# Out:
# Shape: (5, 2)
#
# Data Types:
# id    int64
# hr    int64
# dtype: object
#
# Missing Values:
# id    0
# hr    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
plt.plot(df["id"], df["hr"], linestyle='--', marker="o")
plt.xlabel("Participant ID")
plt.ylabel("Heart Rate (bpm)")
plt.title("Heart Rate by Participant")
plt.grid(True)
plt.show()
